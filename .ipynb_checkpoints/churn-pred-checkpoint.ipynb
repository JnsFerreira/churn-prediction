# %% [markdown]
# <h1 align='center'> Previsão de Churn - Telco<h1>
#
# ## Bibliotecas iniciais

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Lendo o arquivo .csv
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
#Primeiras 5 linhas do DataFrame
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#Últimas 5 linhas dos DataFrame
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# Tipo de cada coluna 
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
def check_fill(df):
    #Cria um dicionario vazio
    fill_cols = {}
    
    #Percorre todas as colunas do dataframe
    for column in df.columns:
        fill_cols.update({column :df[column].isna().count() / df.shape[0] *100})
    
    #Converte o dicionário em um pandas DataFrame e renomeia as colunas
    df_fill = pd.DataFrame.from_dict(fill_cols, orient='index')
    df_fill.reset_index(inplace=True)
    df_fill.rename(columns={'index':'columnName',0:'fillPercent'}, inplace=True)
    
    #Retorna o DataFrame formatado
    return df_fill

# %%
#Aplicando a função 'check_fill'
df_fill = check_fill(df)

#Checando os valores obtidos
df_fill
# Out:
#           columnName  fillPercent
# 0       TotalCharges        100.0
# 1              Churn        100.0
# 2            Partner        100.0
# 3   DeviceProtection        100.0
# 4     MonthlyCharges        100.0
# 5     OnlineSecurity        100.0
# 6             gender        100.0
# 7    StreamingMovies        100.0
# 8   PaperlessBilling        100.0
# 9         Dependents        100.0
# 10          Contract        100.0
# 11     PaymentMethod        100.0
# 12      PhoneService        100.0
# 13            tenure        100.0
# 14   InternetService        100.0
# 15     SeniorCitizen        100.0
# 16     MultipleLines        100.0
# 17       TechSupport        100.0
# 18      OnlineBackup        100.0
# 19        customerID        100.0
# 20       StreamingTV        100.0

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
cols=['MultipleLines',
'OnlineSecurity',
'OnlineBackup',
'DeviceProtection',
'TechSupport',
'StreamingTV',
'StreamingMovies']

# %%
for col in cols:
    print(df[col].unique())
# Out:
# ['No phone service' 'No' 'Yes']
# ['No' 'Yes' 'No internet service']
# ['Yes' 'No' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']

# %%
#Conforme visto na célula acima, podemos substituir os valores 'No internet service' ou 'No phone service' 
# apenas por 'No'

for col in cols:
    df[col].replace(['No phone service', 'No internet service'], 'No', inplace=True)
    print(df[col].unique())
# Out:
# ['No' 'Yes']
# ['No' 'Yes']
# ['Yes' 'No']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# Realizando o agrupamento por faixas:
#
#
# * Grupo 0 = 0-12
# * Grupo 1 = 13-24
# * Grupo 2 = 25-36
# * Grupo 3 = 37-48
# * Grupo 4 = 48-60
# * Grupo 5 = 60+

# %%
#Range dos grupos
bins = [0,12,24,36,48,60,1000]

#Labels dos grupos
labels=[0,1,2,3,4,5]

#Mapeando de acordo com os dados fornecidos acima 
df['tenure'] = pd.cut(df['tenure'], bins=bins, labels=labels, include_lowest=True)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No      0           No
# 1  5575-GNVDE    Male              0      No         No      2          Yes
# 2  3668-QPYBK    Male              0      No         No      0          Yes
# 3  7795-CFOCW    Male              0      No         No      3           No
# 4  9237-HQITU  Female              0      No         No      0          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(df['InternetService'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['_InternetService'] = le.fit_transform(df['InternetService'])

# %%
# Out:
#     _InternetService InternetService
# 0                  0             DSL
# 1                  0             DSL
# 2                  0             DSL
# 3                  0             DSL
# 4                  1     Fiber optic
# 5                  1     Fiber optic
# 6                  1     Fiber optic
# 7                  0             DSL
# 8                  1     Fiber optic
# 9                  0             DSL
# 10                 0             DSL
# 11                 2              No
# 12                 1     Fiber optic
# 13                 1     Fiber optic
# 14                 1     Fiber optic
# 15                 1     Fiber optic
# 16                 2              No
# 17                 1     Fiber optic
# 18                 0             DSL
# 19                 1     Fiber optic
# 20                 0             DSL
# 21                 2              No
# 22                 2              No
# 23                 0             DSL
# ...
